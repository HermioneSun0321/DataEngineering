# %%
# Import libraries
import pandas as pd
import numpy as np
import os

from dvc.api import make_checkpoint

# Display full outputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import warnings
warnings.filterwarnings("ignore")

# %%
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/project/spark-3.2.1-bin-hadoop3.2"

# %%
from pyspark.sql import SparkSession
spark = SparkSession \
    .builder \
    .appName("PySpark App") \
    .config("spark.jars", "postgresql-42.3.2.jar") \
    .getOrCreate()

# %% [markdown]
# ### Data Transformation

# %%
# Read film data
df_film = spark.read.parquet("/project/Individual/parquet_files/origin.parquet").toPandas()
make_checkpoint()
df_film
# Out:
#      place                                         title  year  \
# 0      187  Harry Potter and the Deathly Hallows: Part 2  2011
# 1      188                   Mr Smith Goes to Washington  1939
# 2      189                      The Grand Budapest Hotel  2014
# 3      190                                   Sherlock Jr  1924
# 4      191                         Le salaire de la peur  1953
# ..     ...                                           ...   ...
# 245     58                           The Lives of Others  2006
# 246     59                                   Sunset Blvd  1950
# 247     60                                Paths of Glory  1957
# 248     61                                   The Shining  1980
# 249     62                            The Great Dictator  1940
#
#                              director                                cast  \
# 0                         David Yates       Daniel Radcliffe, Emma Watson
# 1                         Frank Capra          James Stewart, Jean Arthur
# 2                        Wes Anderson    Ralph Fiennes, F. Murray Abraham
# 3                       Buster Keaton      Buster Keaton, Kathryn McGuire
# 4               Henri-Georges Clouzot         Yves Montand, Charles Vanel
# ..                                ...                                 ...
# 245  Florian Henckel von Donnersmarck         Ulrich Mühe, Martina Gedeck
# 246                      Billy Wilder      William Holden, Gloria Swanson
# 247                   Stanley Kubrick          Kirk Douglas, Ralph Meeker
# 248                   Stanley Kubrick      Jack Nicholson, Shelley Duvall
# 249                   Charles Chaplin   Charles Chaplin, Paulette Goddard
#
#      rating      genre     duration  domestic_k  international_k  worldwide_k  \
# 0    8.0748  Adventure  2 hr 10 min  381447.587       960912.354  1342359.942
# 1    8.0725     Comedy   2 hr 9 min     144.738          144.738     1900.000
# 2    8.0716  Adventure  1 hr 39 min   59301.324       113780.865   173082.189
# 3    8.0704     Action       45 min       0.000            0.000        0.000
# 4    8.0702  Adventure  2 hr 11 min       0.000            0.000        0.000
# ..      ...        ...          ...         ...              ...          ...
# 245  8.3869      Drama  2 hr 17 min   11286.112        66070.830    77356.942
# 246  8.3838      Drama  1 hr 50 min     299.645            0.428      300.073
# 247  8.3712      Drama  1 hr 28 min       0.000            0.000        0.000
# 248  8.3683      Drama  2 hr 26 min   45634.352         1665.108    47299.460
# 249  8.3667     Comedy   2 hr 5 min       0.000            0.000        0.000
#
#                   distributor
# 0                Warner Bros.
# 1           Columbia Pictures
# 2    Fox Searchlight Pictures
# 3                           0
# 4                           0
# ..                        ...
# 245    Sony Pictures Classics
# 246        Paramount Pictures
# 247            United Artists
# 248              Warner Bros.
# 249            United Artists
#
# [250 rows x 12 columns]

# %%
# A glance at the duration column
df_film['duration']
# Out:
# 0      2 hr 10 min
# 1       2 hr 9 min
# 2      1 hr 39 min
# 3           45 min
# 4      2 hr 11 min
#           ...
# 245    2 hr 17 min
# 246    1 hr 50 min
# 247    1 hr 28 min
# 248    2 hr 26 min
# 249     2 hr 5 min
# Name: duration, Length: 250, dtype: object

# %%
# Change the format of unique running times
# Such as less than 1 hour (no 'hr') or exactly whole hours (no 'min')
less_1hr = df_film[df_film['duration'].str.contains('hr')== False]
less_1hr
# Out:
#    place        title  year       director                             cast  \
# 3    190  Sherlock Jr  1924  Buster Keaton   Buster Keaton, Kathryn McGuire
#
#    rating   genre duration  domestic_k  international_k  worldwide_k  \
# 3  8.0704  Action   45 min         0.0              0.0          0.0
#
#   distributor
# 3           0

# %%
whole_hrs = df_film[df_film['duration'].str.contains('min')== False]
whole_hrs
# Out:
#      place                    title  year          director  \
# 16     203       Mad Max: Fury Road  2015     George Miller
# 24     211                  Platoon  1986      Oliver Stone
# 25     212                    Rocky  1976  John G. Avildsen
# 72      71                 Oldeuboi  2003    Park Chan-wook
# 134    133  The Wolf of Wall Street  2013   Martin Scorsese
#
#                                  cast  rating      genre duration  domestic_k  \
# 16         Tom Hardy, Charlize Theron  8.0611     Action     2 hr  154109.060
# 24        Charlie Sheen, Tom Berenger  8.0478      Drama     2 hr  138530.565
# 25    Sylvester Stallone, Talia Shire  8.0471      Drama     2 hr  117235.147
# 72           Choi Min-sik, Yoo Ji-Tae  8.3201     Action     2 hr     707.481
# 134     Leonardo DiCaprio, Jonah Hill  8.1702  Biography     3 hr  116900.694
#
#      international_k  worldwide_k         distributor
# 16        221600.410   375709.470        Warner Bros.
# 24            15.067   138545.632      Orion Pictures
# 25            15.255   117250.402      United Artists
# 72         14487.112    15194.593              Tartan
# 134       275100.000   392000.694  Paramount Pictures

# %%
# Mannually fix the format
df_film.at[3, 'duration'] = '0 hr 45 min'
df_film.at[16, 'duration'] = '2 hr 0 min'
df_film.at[24, 'duration'] = '2 hr 0 min'
df_film.at[25, 'duration'] = '2 hr 0 min'
df_film.at[72, 'duration'] = '2 hr 0 min'
df_film.at[134, 'duration'] = '3 hr 0 min'
make_checkpoint()

# %%
# Clean the duration column for transformation
df_film['duration'] = df_film['duration'].str.replace(' ', '')
df_film['duration'] = df_film['duration'].str.replace('min', '')
df_film['duration'] = df_film['duration'].str.replace('hr', ':')
make_checkpoint()

# %%
df_film['duration']
# Out:
# 0      2:10
# 1       2:9
# 2      1:39
# 3      0:45
# 4      2:11
#        ...
# 245    2:17
# 246    1:50
# 247    1:28
# 248    2:26
# 249     2:5
# Name: duration, Length: 250, dtype: object

# %%
# Convert duration into minutes
df_film['duration'] = df_film['duration'].str.split(':').apply(lambda x: int(x[0]) * 60 + int(x[1]))
make_checkpoint()

# %%
# Create duration rank column
df_film['duration_rank'] = df_film['duration'].rank(ascending=False)
make_checkpoint()

# %%
# Create duration by genre column
df_film['duration_rank_bygenre'] = df_film.groupby('genre')['duration'].rank(ascending=False)
make_checkpoint()

# %%
# Calculate the percentage of domestic and international box office income
df_film['dom_pct'] = df_film['domestic_k']/df_film['worldwide_k']
df_film['int_pct'] = df_film['international_k']/df_film['worldwide_k']
df_film['dom_pct'] = df_film['dom_pct'].round(decimals = 4)
df_film['int_pct'] = df_film['int_pct'].round(decimals = 4)
make_checkpoint()

# %%
# Check the realistic feasibility
df_film['check'] = df_film['dom_pct'] + df_film['int_pct']
df_film['check'] = df_film['check'].fillna(0)
make_checkpoint()

# Find the rows that do not make sense in real life
df_film.loc[(df_film['check'] != 1.0000) & (df_film['check'] != 0)]
# Out:
#      place                                       title  year  \
# 1      188                 Mr Smith Goes to Washington  1939
# 18     205                  La passion de Jeanne d'Arc  1928
# 27     214                                 Stand by Me  1986
# 37     224                                The Exorcist  1973
# 58     245                                      Gandhi  1982
# 61     248                        Beauty and the Beast  1991
# 76      75                                    Das Boot  1981
# 87      86  Star Wars: Episode VI - Return of the Jedi  1983
# 104    103                           Full Metal Jacket  1987
# 160    159         Lock, Stock and Two Smoking Barrels  1998
# 164    163                The Bridge on the River Kwai  1957
# 179    178                           Bacheha-Ye aseman  1997
# 202     15                     The Empire Strikes Back  1980
# 214     27                                   Star Wars  1977
# 216     29                  Terminator 2: Judgment Day  1991
# 226     39                          The Usual Suspects  1995
# 235     48                              Hotaru no haka  1988
#
#                  director                                         cast  \
# 1             Frank Capra                   James Stewart, Jean Arthur
# 18    Carl Theodor Dreyer             Maria Falconetti, Eugene Silvain
# 27             Rob Reiner                   Wil Wheaton, River Phoenix
# 37       William Friedkin                 Ellen Burstyn, Max von Sydow
# 58   Richard Attenborough                   Ben Kingsley, John Gielgud
# 61         Gary Trousdale                   Paige O'Hara, Robby Benson
# 76      Wolfgang Petersen          Jürgen Prochnow, Herbert Grönemeyer
# 87       Richard Marquand                   Mark Hamill, Harrison Ford
# 104       Stanley Kubrick                 Matthew Modine, R. Lee Ermey
# 160           Guy Ritchie               Jason Flemyng, Dexter Fletcher
# 164            David Lean                William Holden, Alec Guinness
# 179          Majid Majidi   Mohammad Amir Naji, Amir Farrokh Hashemian
# 202        Irvin Kershner                   Mark Hamill, Harrison Ford
# 214          George Lucas                   Mark Hamill, Harrison Ford
# 216         James Cameron        Arnold Schwarzenegger, Linda Hamilton
# 226          Bryan Singer                  Kevin Spacey, Gabriel Byrne
# 235         Isao Takahata             Tsutomu Tatsumi, Ayano Shiraishi
#
#      rating      genre  duration  domestic_k  international_k  worldwide_k  \
# 1    8.0725     Comedy       129     144.738          144.738     1900.000
# 18   8.0578  Biography       110      21.877           21.877        6.408
# 27   8.0429  Adventure        89   52287.414        52287.414      242.795
# 37   8.0289     Horror       122  233005.644       136017.945   441306.145
# 58   8.0078  Biography       191   52767.889        52767.889      131.153
# 61   8.0045  Animation        84  218967.620       186043.788   424967.620
# 76   8.3124      Drama       149   11487.676        11487.676       26.994
# 87   8.2687     Action       131  309306.177       122009.457   475106.177
# 104  8.2408      Drama       116   46357.676        46357.676     2217.307
# 160  8.1244     Action       107    3753.929         3753.929      143.321
# 164  8.1158  Adventure       161   27200.000        27200.000     3000.000
# 179  8.0813      Drama        89     933.933          933.933       20.100
# 202  8.7019     Action       124  292753.960       190685.234   538375.067
# 214  8.5551     Action       121  460998.507       195751.992   775398.007
# 216  8.5345     Action       137  205881.154       312106.698   520881.154
# 226  8.4780      Crime       106   23341.568        23341.568      645.363
# 235  8.4460  Animation        89     516.962          516.962      158.101
#
#                              distributor  duration_rank  \
# 1                      Columbia Pictures          115.0
# 18                           Janus Films          182.5
# 27                     Columbia Pictures          235.5
# 37                          Warner Bros.          139.5
# 58                     Columbia Pictures            9.0
# 61   Walt Disney Studios Motion Pictures          245.0
# 76                     Columbia Pictures           55.5
# 87                 Twentieth Century Fox          101.5
# 104                         Warner Bros.          167.0
# 160                Gramercy Pictures (I)          190.5
# 164                    Columbia Pictures           37.0
# 179                              Miramax          235.5
# 202                Twentieth Century Fox          133.0
# 214                Twentieth Century Fox          145.0
# 216                     TriStar Pictures           82.5
# 226                Gramercy Pictures (I)          194.0
# 235                        Fathom Events          235.5
#
#      duration_rank_bygenre   dom_pct   int_pct     check
# 1                      3.5    0.0762    0.0762    0.1524
# 18                    22.0    3.4140    3.4140    6.8280
# 27                    35.0  215.3562  215.3562  430.7124
# 37                     1.0    0.5280    0.3082    0.8362
# 58                     2.0  402.3384  402.3384  804.6768
# 61                     5.0    0.5153    0.4378    0.9531
# 76                    12.5  425.5641  425.5641  851.1282
# 87                    28.0    0.6510    0.2568    0.9078
# 104                   49.5   20.9072   20.9072   41.8144
# 160                   44.5   26.1925   26.1925   52.3850
# 164                    7.5    9.0667    9.0667   18.1334
# 179                   64.5   46.4643   46.4643   92.9286
# 202                   31.0    0.5438    0.3542    0.8980
# 214                   33.0    0.5945    0.2525    0.8470
# 216                   21.0    0.3953    0.5992    0.9945
# 226                   27.0   36.1681   36.1681   72.3362
# 235                    3.0    3.2698    3.2698    6.5396

# %%
# Mannually fix the films that do not have international incomes
df_film.at[1, 'international_k'] = 0.000
df_film.at[1, 'worldwide_k'] = 144.738
df_film.at[18, 'international_k'] = 0.000
df_film.at[18, 'worldwide_k'] = 21.877
df_film.at[27, 'international_k'] = 0.000
df_film.at[27, 'worldwide_k'] = 52287.414
df_film.at[58, 'international_k'] = 0.000
df_film.at[58, 'worldwide_k'] = 52767.889
df_film.at[76, 'international_k'] = 0.000
df_film.at[76, 'worldwide_k'] = 11487.676
df_film.at[104, 'international_k'] = 0.000
df_film.at[104, 'worldwide_k'] = 46357.676
df_film.at[160, 'international_k'] = 0.000
df_film.at[160, 'worldwide_k'] = 3753.929
df_film.at[164, 'international_k'] = 0.000
df_film.at[164, 'worldwide_k'] = 27200.000
df_film.at[179, 'international_k'] = 0.000
df_film.at[179, 'worldwide_k'] = 933.933
df_film.at[226, 'international_k'] = 0.000
df_film.at[226, 'worldwide_k'] = 23341.568
df_film.at[235, 'international_k'] = 0.000
df_film.at[235, 'worldwide_k'] = 516.962
make_checkpoint()

# %%
# Find other missing box office incomes data
df_film.loc[(df_film['domestic_k'] == 0) & (df_film['international_k'] == 0) & (df_film['worldwide_k'] == 0)]
# Out:
#      place                              title  year               director  \
# 3      190                        Sherlock Jr  1924          Buster Keaton
# 4      191              Le salaire de la peur  1953  Henri-Georges Clouzot
# 6      193                       Barry Lyndon  1975        Stanley Kubrick
# 8      195                Det sjunde inseglet  1957         Ingmar Bergman
# 12     199                              Klaus  2019          Sergio Pablos
# 17     204                       Mary and Max  2009            Adam Elliot
# 22     209                   Tôkyô monogatari  1953           Yasujirô Ozu
# 42     229                            Rebecca  1940       Alfred Hitchcock
# 43     230                 To Be or Not to Be  1942         Ernst Lubitsch
# 44     231                The Grapes of Wrath  1940              John Ford
# 45     232                     Cool Hand Luke  1967       Stuart Rosenberg
# 46     233                Hachi: A Dog's Tale  2009        Lasse Hallström
# 48     235                        Dersu Uzala  1975         Akira Kurosawa
# 49     236                     Babam ve Oglum  2005            Cagan Irmak
# 51     238                            Persona  1966         Ingmar Bergman
# 55     242              It Happened One Night  1934            Frank Capra
# 64      63        Witness for the Prosecution  1957           Billy Wilder
# 93      92                  Tengoku to jigoku  1963         Akira Kurosawa
# 97      96  M - Eine Stadt sucht einen Mörder  1931             Fritz Lang
# 105    104                   Double Indemnity  1944           Billy Wilder
# 110    109                          The Sting  1973        George Roy Hill
# 112    111                           Hamilton  2020            Thomas Kail
# 126    125         Per qualche dollaro in più  1965           Sergio Leone
# 129    128                            The Kid  1921        Charles Chaplin
# 130    129                   Some Like It Hot  1959           Billy Wilder
# 135    134              Judgment at Nuremberg  1961         Stanley Kramer
# 145    144                            Yôjinbô  1961         Akira Kurosawa
# 146    145   The Treasure of the Sierra Madre  1948            John Huston
# 147    146                           Rashômon  1950         Akira Kurosawa
# 148    147                   The Great Escape  1963           John Sturges
# 174    173                      The Gold Rush  1925        Charles Chaplin
# 176    175                  On the Waterfront  1954             Elia Kazan
# 180    179                        The General  1926         Clyde Bruckman
# 183    182                    Smultronstället  1957         Ingmar Bergman
# 192      5                       12 Angry Men  1957           Sidney Lumet
# 234     47                            Seppuku  1962       Masaki Kobayashi
# 247     60                     Paths of Glory  1957        Stanley Kubrick
# 249     62                 The Great Dictator  1940        Charles Chaplin
#
#                                        cast  rating      genre  duration  \
# 3            Buster Keaton, Kathryn McGuire  8.0704     Action        45
# 4               Yves Montand, Charles Vanel  8.0702  Adventure       131
# 6              Ryan O'Neal, Marisa Berenson  8.0686  Adventure       185
# 8         Max von Sydow, Gunnar Björnstrand  8.0674      Drama        96
# 12          Jason Schwartzman, J.K. Simmons  8.0652  Adventure        96
# 17    Toni Collette, Philip Seymour Hoffman  8.0604  Animation        92
# 22           Chishû Ryû, Chieko Higashiyama  8.0522      Drama       136
# 42          Laurence Olivier, Joan Fontaine  8.0234      Drama       130
# 43               Carole Lombard, Jack Benny  8.0234     Comedy        99
# 44                Henry Fonda, Jane Darwell  8.0225      Drama       129
# 45              Paul Newman, George Kennedy  8.0219      Crime       127
# 46                 Richard Gere, Joan Allen  8.0217  Biography        93
# 48             Maksim Munzuk, Yuriy Solomin  8.0205  Adventure       142
# 49             Eser Sariyar, Çetin Tekindor  8.0169      Drama       112
# 51              Bibi Andersson, Liv Ullmann  8.0163      Drama        85
# 55           Clark Gable, Claudette Colbert  8.0137     Comedy       105
# 64           Tyrone Power, Marlene Dietrich  8.3558      Crime       116
# 93              Toshirô Mifune, Yutaka Sada  8.2613      Crime       143
# 97               Peter Lorre, Ellen Widmann  8.2560      Crime       117
# 105        Fred MacMurray, Barbara Stanwyck  8.2383      Crime       107
# 110             Paul Newman, Robert Redford  8.2292     Comedy       129
# 112        Lin-Manuel Miranda, Phillipa Soo  8.2277  Biography       160
# 126           Clint Eastwood, Lee Van Cleef  8.2041    Western       132
# 129         Charles Chaplin, Edna Purviance  8.1951     Comedy        68
# 130             Marilyn Monroe, Tony Curtis  8.1916     Comedy       121
# 135           Spencer Tracy, Burt Lancaster  8.1672      Drama       179
# 145             Toshirô Mifune, Eijirô Tôno  8.1493     Action       110
# 146          Humphrey Bogart, Walter Huston  8.1483  Adventure       126
# 147             Toshirô Mifune, Machiko Kyô  8.1437      Crime        88
# 148             Steve McQueen, James Garner  8.1432  Adventure       172
# 174             Charles Chaplin, Mack Swain  8.0880  Adventure        95
# 176              Marlon Brando, Karl Malden  8.0860      Crime       108
# 180              Buster Keaton, Marion Mack  8.0791     Action        67
# 183         Victor Sjöström, Bibi Andersson  8.0777      Drama        91
# 192                Henry Fonda, Lee J. Cobb  8.9463      Crime        96
# 234         Tatsuya Nakadai, Akira Ishihama  8.4484     Action       133
# 247              Kirk Douglas, Ralph Meeker  8.3712      Drama        88
# 249       Charles Chaplin, Paulette Goddard  8.3667     Comedy       125
#
#      domestic_k  international_k  worldwide_k  \
# 3           0.0              0.0          0.0
# 4           0.0              0.0          0.0
# 6           0.0              0.0          0.0
# 8           0.0              0.0          0.0
# 12          0.0              0.0          0.0
# 17          0.0              0.0          0.0
# 22          0.0              0.0          0.0
# 42          0.0              0.0          0.0
# 43          0.0              0.0          0.0
# 44          0.0              0.0          0.0
# 45          0.0              0.0          0.0
# 46          0.0              0.0          0.0
# 48          0.0              0.0          0.0
# 49          0.0              0.0          0.0
# 51          0.0              0.0          0.0
# 55          0.0              0.0          0.0
# 64          0.0              0.0          0.0
# 93          0.0              0.0          0.0
# 97          0.0              0.0          0.0
# 105         0.0              0.0          0.0
# 110         0.0              0.0          0.0
# 112         0.0              0.0          0.0
# 126         0.0              0.0          0.0
# 129         0.0              0.0          0.0
# 130         0.0              0.0          0.0
# 135         0.0              0.0          0.0
# 145         0.0              0.0          0.0
# 146         0.0              0.0          0.0
# 147         0.0              0.0          0.0
# 148         0.0              0.0          0.0
# 174         0.0              0.0          0.0
# 176         0.0              0.0          0.0
# 180         0.0              0.0          0.0
# 183         0.0              0.0          0.0
# 192         0.0              0.0          0.0
# 234         0.0              0.0          0.0
# 247         0.0              0.0          0.0
# 249         0.0              0.0          0.0
#
#                              distributor  duration_rank  \
# 3                                      0          250.0
# 4                                      0          101.5
# 6                                      0           11.0
# 8                            Janus Films          220.5
# 12                                     0          220.5
# 17                                     0          229.5
# 22                                     0           86.5
# 42                        United Artists          107.5
# 43                        United Artists          211.5
# 44                 Twentieth Century Fox          115.0
# 45                          Warner Bros.          122.5
# 46                                     0          227.5
# 48                                     0           70.5
# 49                                     0          177.0
# 51                                     0          244.0
# 55                     Columbia Pictures          197.0
# 64                        United Artists          167.0
# 93                           Janus Films           67.0
# 97                                     0          162.0
# 105                   Paramount Pictures          190.5
# 110                   Universal Pictures          115.0
# 112  Walt Disney Studios Motion Pictures           39.5
# 126                       United Artists           97.0
# 129                                    0          248.0
# 130                       United Artists          145.0
# 135                       United Artists           16.5
# 145                   Seneca Productions          182.5
# 146                         Warner Bros.          126.0
# 147                   RKO Radio Pictures          239.0
# 148                       United Artists           23.5
# 174                       United Artists          224.0
# 176                    Columbia Pictures          187.5
# 180                       United Artists          249.0
# 183                          Janus Films          231.5
# 192                       United Artists          220.5
# 234                                    0           93.0
# 247                       United Artists          239.0
# 249                       United Artists          129.5
#
#      duration_rank_bygenre  dom_pct  int_pct  check
# 3                     48.0      NaN      NaN    0.0
# 4                     14.0      NaN      NaN    0.0
# 6                      3.0      NaN      NaN    0.0
# 8                     61.0      NaN      NaN    0.0
# 12                    28.5      NaN      NaN    0.0
# 17                     2.0      NaN      NaN    0.0
# 22                    25.0      NaN      NaN    0.0
# 42                    31.0      NaN      NaN    0.0
# 43                    19.0      NaN      NaN    0.0
# 44                    34.5      NaN      NaN    0.0
# 45                    16.5      NaN      NaN    0.0
# 46                    23.0      NaN      NaN    0.0
# 48                    12.0      NaN      NaN    0.0
# 49                    52.0      NaN      NaN    0.0
# 51                    67.0      NaN      NaN    0.0
# 55                    14.0      NaN      NaN    0.0
# 64                    23.0      NaN      NaN    0.0
# 93                    10.0      NaN      NaN    0.0
# 97                    22.0      NaN      NaN    0.0
# 105                   26.0      NaN      NaN    0.0
# 110                    3.5      NaN      NaN    0.0
# 112                    6.5      NaN      NaN    0.0
# 126                    2.0      NaN      NaN    0.0
# 129                   24.0      NaN      NaN    0.0
# 130                   10.0      NaN      NaN    0.0
# 135                    3.0      NaN      NaN    0.0
# 145                   42.5      NaN      NaN    0.0
# 146                   16.0      NaN      NaN    0.0
# 147                   34.0      NaN      NaN    0.0
# 148                    5.0      NaN      NaN    0.0
# 174                   30.5      NaN      NaN    0.0
# 176                   25.0      NaN      NaN    0.0
# 180                   47.0      NaN      NaN    0.0
# 183                   63.0      NaN      NaN    0.0
# 192                   33.0      NaN      NaN    0.0
# 234                   25.0      NaN      NaN    0.0
# 247                   66.0      NaN      NaN    0.0
# 249                    6.5      NaN      NaN    0.0

# %%
# Fill in missing values mannully
df_film.at[4, 'international_k'] = 1.098
df_film.at[4, 'worldwide_k'] = 1.098
df_film.at[6, 'international_k'] = 198.992
df_film.at[6, 'worldwide_k'] = 198.992
df_film.at[8, 'international_k'] = 286.085
df_film.at[8, 'worldwide_k'] = 286.085
df_film.at[17, 'international_k'] = 1740.429
df_film.at[17, 'worldwide_k'] = 1740.429
df_film.at[22, 'international_k'] = 40.468
df_film.at[22, 'worldwide_k'] = 40.468
df_film.at[42, 'international_k'] = 72.275
df_film.at[42, 'worldwide_k'] = 72.275
df_film.at[46, 'international_k'] = 46749.646
df_film.at[46, 'worldwide_k'] = 46749.646
df_film.at[48, 'international_k'] = 14.480
df_film.at[48, 'worldwide_k'] = 14.480
df_film.at[49, 'international_k'] = 18612.999
df_film.at[49, 'worldwide_k'] = 18612.999
df_film.at[51, 'international_k'] = 90.556
df_film.at[51, 'worldwide_k'] = 90.556
df_film.at[64, 'international_k'] = 7.693
df_film.at[64, 'worldwide_k'] = 7.693
df_film.at[93, 'domestic_k'] = 46.808
df_film.at[93, 'worldwide_k'] = 46.808
df_film.at[97, 'domestic_k'] = 35.566
df_film.at[97, 'worldwide_k'] = 35.566
df_film.at[105, 'international_k'] = 14.190
df_film.at[105, 'worldwide_k'] = 14.190
df_film.at[110, 'domestic_k'] = 156000.000
df_film.at[110, 'worldwide_k'] = 156000.000
df_film.at[126, 'domestic_k'] = 15000.000
df_film.at[126, 'worldwide_k'] = 15000.000
df_film.at[129, 'international_k'] = 41.960
df_film.at[129, 'worldwide_k'] = 41.960
df_film.at[130, 'international_k'] = 195.088
df_film.at[130, 'worldwide_k'] = 195.088
df_film.at[135, 'international_k'] = 12.180
df_film.at[135, 'worldwide_k'] = 12.180
df_film.at[146, 'domestic_k'] = 5014.000
df_film.at[146, 'worldwide_k'] = 5014.000
df_film.at[147, 'domestic_k'] = 46.808
df_film.at[147, 'worldwide_k'] = 46.808
df_film.at[148, 'international_k'] = 228.178
df_film.at[148, 'worldwide_k'] = 228.178
df_film.at[174, 'international_k'] = 26.916
df_film.at[174, 'worldwide_k'] = 26.916
df_film.at[183, 'international_k'] = 14.524
df_film.at[183, 'worldwide_k'] = 14.524
df_film.at[192, 'international_k'] = 0.955
df_film.at[192, 'worldwide_k'] = 0.955
df_film.at[234, 'international_k'] = 15.222
df_film.at[234, 'worldwide_k'] = 15.222
df_film.at[247, 'international_k'] = 5.252
df_film.at[247, 'worldwide_k'] = 5.252
df_film.at[249, 'international_k'] = 970.214
df_film.at[249, 'worldwide_k'] = 970.214
make_checkpoint()

# %%
# Check again
df_film['dom_pct'] = df_film['domestic_k']/df_film['worldwide_k']
df_film['int_pct'] = df_film['international_k']/df_film['worldwide_k']
df_film['dom_pct'] = df_film['dom_pct'].round(decimals = 4)
df_film['int_pct'] = df_film['int_pct'].round(decimals = 4)
df_film['check'] = df_film['dom_pct'] + df_film['int_pct']
df_film['check'] = df_film['check'].fillna(0)
make_checkpoint()
df_film['check'].value_counts()
# Out:
# 1.0000    234
# 0.0000     10
# 0.8980      1
# 0.8470      1
# 0.8362      1
# 0.9531      1
# 0.9945      1
# 0.9078      1
# Name: check, dtype: int64

# %%
# Drop the check column
df_film = df_film.drop('check', axis = 1)
make_checkpoint()

# %%
# Create place by genre column
df_film['place_bygenre'] = df_film.groupby('genre')['place'].rank(ascending=False)
make_checkpoint()

# %%
# Create income rank column
df_film['income_rank'] = df_film['worldwide_k'].rank(ascending=False)
make_checkpoint()

# %%
# Create income rank by genre column
df_film['income_rank_bygenre'] = df_film.groupby('genre')['worldwide_k'].rank(ascending=False)
make_checkpoint()

# %%
# Calculate the difference between rating rank (place) and income rank
df_film['rank_diff'] = df_film['income_rank'] - df_film['place']
make_checkpoint()

# %%
# Check for missing values
df_film.isnull().sum()
# Out:
# place                     0
# title                     0
# year                      0
# director                  0
# cast                      0
# rating                    0
# genre                     0
# duration                  0
# domestic_k                0
# international_k           0
# worldwide_k               0
# distributor               0
# duration_rank             0
# duration_rank_bygenre     0
# dom_pct                  10
# int_pct                  10
# place_bygenre             0
# income_rank               0
# income_rank_bygenre       0
# rank_diff                 0
# dtype: int64

# %%
# Fill in NaN with 0
df_film.fillna(0, inplace=True)
make_checkpoint()

# %%
# Check again
df_film.isnull().sum()
# Out:
# place                    0
# title                    0
# year                     0
# director                 0
# cast                     0
# rating                   0
# genre                    0
# duration                 0
# domestic_k               0
# international_k          0
# worldwide_k              0
# distributor              0
# duration_rank            0
# duration_rank_bygenre    0
# dom_pct                  0
# int_pct                  0
# place_bygenre            0
# income_rank              0
# income_rank_bygenre      0
# rank_diff                0
# dtype: int64

# %%
# Adjust the order of the columns
df_film = df_film[['title', 'year', 'director', 'cast', 'distributor', 'genre', 'rating', 'place', 'place_bygenre', 'duration', 'duration_rank', 'duration_rank_bygenre', 'domestic_k', 'international_k', 'worldwide_k', 'dom_pct', 'int_pct', 'income_rank', 'income_rank_bygenre', 'rank_diff']]
make_checkpoint()

# %%
# Final version of film data frame
df_film
# Out:
#                                             title  year  \
# 0    Harry Potter and the Deathly Hallows: Part 2  2011
# 1                     Mr Smith Goes to Washington  1939
# 2                        The Grand Budapest Hotel  2014
# 3                                     Sherlock Jr  1924
# 4                           Le salaire de la peur  1953
# ..                                            ...   ...
# 245                           The Lives of Others  2006
# 246                                   Sunset Blvd  1950
# 247                                Paths of Glory  1957
# 248                                   The Shining  1980
# 249                            The Great Dictator  1940
#
#                              director                                cast  \
# 0                         David Yates       Daniel Radcliffe, Emma Watson
# 1                         Frank Capra          James Stewart, Jean Arthur
# 2                        Wes Anderson    Ralph Fiennes, F. Murray Abraham
# 3                       Buster Keaton      Buster Keaton, Kathryn McGuire
# 4               Henri-Georges Clouzot         Yves Montand, Charles Vanel
# ..                                ...                                 ...
# 245  Florian Henckel von Donnersmarck         Ulrich Mühe, Martina Gedeck
# 246                      Billy Wilder      William Holden, Gloria Swanson
# 247                   Stanley Kubrick          Kirk Douglas, Ralph Meeker
# 248                   Stanley Kubrick      Jack Nicholson, Shelley Duvall
# 249                   Charles Chaplin   Charles Chaplin, Paulette Goddard
#
#                   distributor      genre  rating  place  place_bygenre  \
# 0                Warner Bros.  Adventure  8.0748    187           14.0
# 1           Columbia Pictures     Comedy  8.0725    188            8.0
# 2    Fox Searchlight Pictures  Adventure  8.0716    189           13.0
# 3                           0     Action  8.0704    190           10.0
# 4                           0  Adventure  8.0702    191           12.0
# ..                        ...        ...     ...    ...            ...
# 245    Sony Pictures Classics      Drama  8.3869     58           55.0
# 246        Paramount Pictures      Drama  8.3838     59           54.0
# 247            United Artists      Drama  8.3712     60           53.0
# 248              Warner Bros.      Drama  8.3683     61           52.0
# 249            United Artists     Comedy  8.3667     62           20.0
#
#      duration  duration_rank  duration_rank_bygenre  domestic_k  \
# 0         130          107.5                   15.0  381447.587
# 1         129          115.0                    3.5     144.738
# 2          99          211.5                   26.0   59301.324
# 3          45          250.0                   48.0       0.000
# 4         131          101.5                   14.0       0.000
# ..        ...            ...                    ...         ...
# 245       137           82.5                   24.0   11286.112
# 246       110          182.5                   53.0     299.645
# 247        88          239.0                   66.0       0.000
# 248       146           62.5                   15.5   45634.352
# 249       125          129.5                    6.5       0.000
#
#      international_k  worldwide_k  dom_pct  int_pct  income_rank  \
# 0         960912.354  1342359.942   0.2842   0.7158          4.0
# 1              0.000      144.738   1.0000   0.0000        216.0
# 2         113780.865   173082.189   0.3426   0.6574         87.0
# 3              0.000        0.000   0.0000   0.0000        245.5
# 4              1.098        1.098   0.0000   1.0000        239.0
# ..               ...          ...      ...      ...          ...
# 245        66070.830    77356.942   0.1459   0.8541        114.0
# 246            0.428      300.073   0.9986   0.0014        210.0
# 247            5.252        5.252   0.0000   1.0000        238.0
# 248         1665.108    47299.460   0.9648   0.0352        132.0
# 249          970.214      970.214   0.0000   1.0000        200.0
#
#      income_rank_bygenre  rank_diff
# 0                    1.0     -183.0
# 1                   20.0       28.0
# 2                   20.0     -102.0
# 3                   47.0       55.5
# 4                   36.0       48.0
# ..                   ...        ...
# 245                 20.0       56.0
# 246                 57.0      151.0
# 247                 67.0      178.0
# 248                 26.0       71.0
# 249                 17.0      138.0
#
# [250 rows x 20 columns]

# %%
# Convert the data frame into spark data frame
df_film_spark = spark.createDataFrame(df_film)

# %%
df_film_spark.printSchema()
# Out:
# root
#  |-- title: string (nullable = true)
#  |-- year: long (nullable = true)
#  |-- director: string (nullable = true)
#  |-- cast: string (nullable = true)
#  |-- distributor: string (nullable = true)
#  |-- genre: string (nullable = true)
#  |-- rating: double (nullable = true)
#  |-- place: long (nullable = true)
#  |-- place_bygenre: double (nullable = true)
#  |-- duration: long (nullable = true)
#  |-- duration_rank: double (nullable = true)
#  |-- duration_rank_bygenre: double (nullable = true)
#  |-- domestic_k: double (nullable = true)
#  |-- international_k: double (nullable = true)
#  |-- worldwide_k: double (nullable = true)
#  |-- dom_pct: double (nullable = true)
#  |-- int_pct: double (nullable = true)
#  |-- income_rank: double (nullable = true)
#  |-- income_rank_bygenre: double (nullable = true)
#  |-- rank_diff: double (nullable = true)

# %%
# Convert the data frame into parquet format
df_film_spark.write.parquet("/project/Individual/parquet_files/film.parquet", mode = 'overwrite')
make_checkpoint()
